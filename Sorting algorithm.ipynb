# %%
def selectionSort(arr):
    n = len(arr)
    for i in range(n - 1):
        min = i # the smallest number
        for j in range(i+1, n):
            if arr[j] < arr[min]:
                min = j
        arr[i], arr[min] = arr[min], arr[i] # 정렬할 부분의 맨 앞의 원소와 가장 작은 원소를 swap
    return arr

if __name__ == "__main__":
    unsortedArr = [8, 31, 48, 73, 3, 65, 20, 29, 11, 15]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    sortedArr = selectionSort(unsortedArr)
    print(f'단순 선택 정렬 후 배열: {sortedArr}')
# Out:
# 정렬되지 않은 배열: [8, 31, 48, 73, 3, 65, 20, 29, 11, 15]
# 단순 선택 정렬 후 배열: [3, 8, 11, 15, 20, 29, 31, 48, 65, 73]

# %%
def selectionSort(arr):
    n = len(arr)
    cnt = 0
    cnt2 = 0
    for i in range(n - 1):
        min = i # the smallest number
        for j in range(i+1, n):
            cnt += 1
            if arr[j] < arr[min]:
                min = j
        arr[i], arr[min] = arr[min], arr[i] # 정렬할 부분의 맨 앞의 원소와 가장 작은 원소를 swap
        cnt2 += 1
    return arr, cnt, cnt2

if __name__ == "__main__":
    unsortedArr = [8, 31, 48, 73, 3, 65, 20, 29, 11, 15]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr = selectionSort(unsortedArr)
    print(f'단순 선택 정렬 후 배열: {sortedArr[0]}')
    print(f'원솟값을 비교하는 횟수: {sortedArr[1]}')
    print(f'정렬을 위한 총 swap 횟수: {sortedArr[2]}')
# Out:
# 정렬되지 않은 배열: [8, 31, 48, 73, 3, 65, 20, 29, 11, 15]
#
# 단순 선택 정렬 후 배열: [3, 8, 11, 15, 20, 29, 31, 48, 65, 73]
# 원솟값을 비교하는 횟수: 45
# 정렬을 위한 총 swap 횟수: 9

# %%
def bubbleSort(arr):
    n = len(arr)
    cnt = 0
    cnt2 = 0
    for i in range(n-1): # 패스(pass)
        print(f'패스 {i+1}')
        for j in range(n-1, i, -1):
            for m in range(0, n-1):
                print(f'{arr[m]:2}' + (' ' if m != j-1 else
                                       ' +' if arr[j-1] > arr[j] else ' -'),
                      end='')
            print(f'{arr[n-1]:2}')
            cnt += 1
            if arr[j-1] > arr[j]:
                arr[j - 1], arr[j] = arr[j], arr[j-1] # swap
                cnt2 += 1
        print()
    return arr, cnt, cnt2
                
if __name__ == "__main__":
    unsortedArr = [6, 4, 3, 7, 1, 9, 8]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr = bubbleSort(unsortedArr)
    print(f'버블 정렬 후 배열: {sortedArr[0]}')
    print(f'원솟값을 비교하는 횟수: {sortedArr[1]}')
    print(f'정렬을 위한 총 swap 횟수: {sortedArr[2]}')
# Out:
# 정렬되지 않은 배열: [6, 4, 3, 7, 1, 9, 8]
#
# 패스 1
#  6  4  3  7  1  9 + 8
#  6  4  3  7  1 - 8  9
#  6  4  3  7 + 1  8  9
#  6  4  3 + 1  7  8  9
#  6  4 + 1  3  7  8  9
#  6 + 1  4  3  7  8  9
#
# 패스 2
#  1  6  4  3  7  8 - 9
#  1  6  4  3  7 - 8  9
#  1  6  4  3 - 7  8  9
#  1  6  4 + 3  7  8  9
#  1  6 + 3  4  7  8  9
#
# 패스 3
#  1  3  6  4  7  8 - 9
#  1  3  6  4  7 - 8  9
#  1  3  6  4 - 7  8  9
#  1  3  6 + 4  7  8  9
#
# 패스 4
#  1  3  4  6  7  8 - 9
#  1  3  4  6  7 - 8  9
#  1  3  4  6 - 7  8  9
#
# 패스 5
#  1  3  4  6  7  8 - 9
#  1  3  4  6  7 - 8  9
#
# 패스 6
#  1  3  4  6  7  8 - 9
#
# 버블 정렬 후 배열: [1, 3, 4, 6, 7, 8, 9]
# 원솟값을 비교하는 횟수: 21
# 정렬을 위한 총 swap 횟수: 8

# %%
def bubbleSort(arr):
    n = len(arr)
    cnt = 0
    cnt2 = 0
    for i in range(n-1): # 패스(pass)
        exchange = 0 # 패스에서 swap 횟수
        print(f'패스 {i+1}')
        for j in range(n-1, i, -1):
            for m in range(0, n-1):
                print(f'{arr[m]:2}' + (' ' if m != j-1 else
                                       ' +' if arr[j-1] > arr[j] else ' -'),
                      end='')
            print(f'{arr[n-1]:2}')
            cnt += 1
            if arr[j-1] > arr[j]:
                arr[j - 1], arr[j] = arr[j], arr[j-1] # swap
                exchange += 1
                cnt2 += 1
        print()
        if exchange == 0:
            break
    return arr, cnt, cnt2
                
if __name__ == "__main__":
    unsortedArr = [6, 4, 3, 7, 1, 9, 8]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr = bubbleSort(unsortedArr)
    print(f'버블 정렬 후 배열: {sortedArr[0]}')
    print(f'원솟값을 비교하는 횟수: {sortedArr[1]}')
    print(f'정렬을 위한 총 swap 횟수: {sortedArr[2]}')
# Out:
# 정렬되지 않은 배열: [6, 4, 3, 7, 1, 9, 8]
#
# 패스 1
#  6  4  3  7  1  9 + 8
#  6  4  3  7  1 - 8  9
#  6  4  3  7 + 1  8  9
#  6  4  3 + 1  7  8  9
#  6  4 + 1  3  7  8  9
#  6 + 1  4  3  7  8  9
#
# 패스 2
#  1  6  4  3  7  8 - 9
#  1  6  4  3  7 - 8  9
#  1  6  4  3 - 7  8  9
#  1  6  4 + 3  7  8  9
#  1  6 + 3  4  7  8  9
#
# 패스 3
#  1  3  6  4  7  8 - 9
#  1  3  6  4  7 - 8  9
#  1  3  6  4 - 7  8  9
#  1  3  6 + 4  7  8  9
#
# 패스 4
#  1  3  4  6  7  8 - 9
#  1  3  4  6  7 - 8  9
#  1  3  4  6 - 7  8  9
#
# 버블 정렬 후 배열: [1, 3, 4, 6, 7, 8, 9]
# 원솟값을 비교하는 횟수: 18
# 정렬을 위한 총 swap 횟수: 8

# %%
def shaker_sort_verbose(arr):
    """"셰이커 정렬(정렬 과정을 출력)"""
    ccnt = 0  # 비교 횟수
    scnt = 0  # 교환 횟수
    left = 0
    n = len(arr)
    right = len(arr) - 1
    last = right
    i = 0
    while left < right:
        print(f'패스{i + 1}')
        i += 1
        for j in range(right, left, -1):
            for m in range(0, n - 1):
               print(f'{arr[m]:2}' + ('  ' if m != j - 1 else
                                    ' +' if arr[j - 1] > arr[j] else ' -'),
                     end='')
            print(f'{arr[n - 1]:2}')
            ccnt += 1
            if arr[j - 1] > arr[j]:
                scnt += 1
                arr[j - 1], arr[j] = arr[j], arr[j - 1]
                last = j
        left = last
        for m in range(0, n - 1):
           print(f'{arr[m]:2}', end='  ')
        print(f'{arr[n - 1]:2}')

        if (left == right):
             break
        print(f'패스 {i + 1}')
        i += 1
        for j in range(left, right):
            for m in range(0, n - 1):
               print(f'{arr[m]:2}' + ('  ' if m != j else
                                    ' +' if arr[j] > arr[j + 1] else ' -'),
                     end='')
            print(f'{arr[n - 1]:2}')
            ccnt += 1
            if arr[j] > arr[j + 1]:
                scnt += 1
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                last = j
        right = last
        for m in range(0, n - 1):
           print(f'{arr[m]:2}', end='  ')
        print(f'{arr[n - 1]:2}')
    print(f'비교를 {ccnt}번 했습니다.')
    print(f'교환을 {scnt}번 했습니다.')

if __name__ == '__main__':
    print('셰이커 정렬을 수행합니다.')

    arr = [23, 78, 45, 8, 32, 56]

    shaker_sort_verbose(arr)  # 배열 x를 단순 교환 정렬

    print('오름차순으로 정렬했습니다.')
# Out:
# 셰이커 정렬을 수행합니다.
# 패스1
# 23  78  45   8  32 -56
# 23  78  45   8 -32  56
# 23  78  45 + 8  32  56
# 23  78 + 8  45  32  56
# 23 + 8  78  45  32  56
#  8  23  78  45  32  56
# 패스 2
#  8  23 -78  45  32  56
#  8  23  78 +45  32  56
#  8  23  45  78 +32  56
#  8  23  45  32  78 +56
#  8  23  45  32  56  78
# 패스3
#  8  23  45  32 -56  78
#  8  23  45 +32  56  78
#  8  23 -32  45  56  78
#  8  23  32  45  56  78
# 패스 4
#  8  23  32  45 -56  78
#  8  23  32  45  56  78
# 비교를 13번 했습니다.
# 교환을 7번 했습니다.
# 오름차순으로 정렬했습니다.

# %%
# Implementation to straight insertion sort
def insertionSort(arr):
    n = len(arr)
    cnt = 0
    cnt2 = 0
    for i in range(1, n):
        j = i
        tmp = arr[i]
        while j > 0 and arr[j - 1] > tmp:
            arr[j] = arr[j - 1]
            j -= 1
            cnt += 1
        arr[j] = tmp # swap
        cnt2 += 1
    return arr, cnt, cnt2

if __name__ == "__main__":
    unsortedArr = [6, 4, 3, 7, 1, 9, 8]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr =insertionSort(unsortedArr)
    print(f'단순 삽입 정렬 후 배열: {sortedArr[0]}')
    print(f'원솟값을 비교하는 횟수: {sortedArr[1]}')
    print(f'정렬을 위한 총 swap 횟수: {sortedArr[2]}')
# Out:
# 정렬되지 않은 배열: [6, 4, 3, 7, 1, 9, 8]
#
# 단순 삽입 정렬 후 배열: [1, 3, 4, 6, 7, 8, 9]
# 원솟값을 비교하는 횟수: 8
# 정렬을 위한 총 swap 횟수: 6

# %%
# Implementation to binary insertion sort
def binaryInsertionSort(arr):
    n = len(arr)

    for i in range(1, n):
        key = arr[i]
        pointLeft = 0 # 검색 범위의 맨 앞 원소 idx
        pointRight = i-1 # 검색 범위의 맨 끝 원소 idx
        
        while True:
            pointCenter = (pointLeft + pointRight) // 2 # 검색 범위의 가운데 원소 idx
            if arr[pointCenter] == key: # 검색 성공
                break
            elif arr[pointCenter] < key: # 검색 범위를 뒤쪽 절반으로 좁힘
                pointLeft = pointCenter + 1 # 시작 위치를 중앙보다 1칸 다음에 있는 idx로 설정
            else: # 검색 범위를 앞쪽 절반으로 좁힘
                pointRight = pointCenter - 1 # 끝 위치를 중앙보다 1칸 앞에 있는 idx로 설정
            if pointLeft > pointRight: # 시작 위치가 끝 위치보다 크다는 것은 검색 실패
                break
        
        pd = pointCenter + 1 if pointLeft <= pointRight else pointRight + 1 # 삽입해야 할 idx
        
        for j in range(i, pd, -1):
            arr[j] = arr[j - 1]
        arr[pd] = key

    return arr

if __name__ == "__main__":
    unsortedArr = [6, 4, 3, 7, 1, 9, 8]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr = binaryInsertionSort(unsortedArr)
    print(f'이진 삽입 정렬 후 배열: {sortedArr}')
# Out:
# 정렬되지 않은 배열: [6, 4, 3, 7, 1, 9, 8]
#
# 이진 삽입 정렬 후 배열: [1, 3, 4, 6, 7, 8, 9]

# %%
# Implementation to shell sort

def shellSort(arr):
    n = len(arr)
    h = n // 2 # h개만큼 떨어져 있는 것을 구해야 함, 초깃값은 전체 배열의 절반값
    while h > 0:
        for i in range(h, n):
            j = i - h
            tmp = arr[i]
            while j >= 0 and arr[j] > tmp:
                arr[j + h] = arr[j]
                j -= h
            arr[j + h] = tmp
        h //= 2
    return arr

if __name__ == "__main__":
    unsortedArr = [6, 4, 3, 7, 5, 1, 9, 8, 2]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr = shellSort(unsortedArr)
    print(f'셸 정렬 후 배열: {sortedArr}')
# Out:
# 정렬되지 않은 배열: [6, 4, 3, 7, 5, 1, 9, 8, 2]
#
# 셸 정렬 후 배열: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Implementation to quick sort

def quickSort(arr, left, right):
    if left >= right: # 원소가 1개인 경우 종료
        return
    pl = left+1 # left cursor
    pr = right # right cursor
    pivot = left
    print(f'arr[{left}] ~ arr[{right}]: ', *arr[left:right+1])   
    while pl <= pr: # pl과 pr이 교차되면 탐색 종료
        while pl <= right and arr[pl] <= arr[pivot]:
            pl += 1 # 배열의 시작부터 오른쪽으로 탐색하며 큰 값 찾기
        while pr > left and arr[pr] >= arr[pivot]:
            pr -= 1 # 배열의 끝부터 왼쪽으로 탐색하며 작은 값 찾기
        if pl > pr:
            arr[pr], arr[pivot] = arr[pivot], arr[pr]
        elif pl <= pr:
            arr[pl], arr[pr] = arr[pr], arr[pl] # Swap


    quickSort(arr, 0, pr-1)
    quickSort(arr, pr+1, right)
    return arr

if __name__ == "__main__":
    print("Quick Sort")
    x = [35, 42, 16, 27, 89, 10, 99, 5, 63]
    print(f'배열 {x}에 대해 퀵 정렬을 수행')
    
    quick_recursion(x)
    
    print(f'정렬 결과: {x}')
# Out:
# Quick Sort
# 배열 [35, 42, 16, 27, 89, 10, 99, 5, 63]에 대해 퀵 정렬을 수행
# arr[0] ~ arr[8]:  35 42 16 27 89 10 99 5 63
# arr[0] ~ arr[3]:  10 5 16 27
# arr[2] ~ arr[3]:  16 27
# arr[0] ~ arr[1]:  5 10
# arr[5] ~ arr[8]:  89 99 42 63
# arr[0] ~ arr[6]:  5 10 16 27 35 42 63
# arr[1] ~ arr[6]:  10 16 27 35 42 63
# arr[2] ~ arr[6]:  16 27 35 42 63
# arr[0] ~ arr[1]:  5 10
# arr[3] ~ arr[6]:  27 35 42 63
# arr[0] ~ arr[2]:  5 10 16
# arr[1] ~ arr[2]:  10 16
# arr[4] ~ arr[6]:  35 42 63
# arr[0] ~ arr[3]:  5 10 16 27
# arr[1] ~ arr[3]:  10 16 27
# arr[2] ~ arr[3]:  16 27
# arr[0] ~ arr[1]:  5 10
# arr[5] ~ arr[6]:  42 63
# arr[0] ~ arr[4]:  5 10 16 27 35
# arr[1] ~ arr[4]:  10 16 27 35
# arr[2] ~ arr[4]:  16 27 35
# arr[0] ~ arr[1]:  5 10
# arr[3] ~ arr[4]:  27 35
# arr[0] ~ arr[2]:  5 10 16
# arr[1] ~ arr[2]:  10 16
# 정렬 결과: [5, 10, 16, 27, 35, 42, 63, 89, 99]

# %%
def bubbleSort(arr):
    n = len(arr)
    cnt = 0
    cnt2 = 0
    for i in range(n-1): # 패스(pass)
        print(f'패스 {i+1}')
        for j in range(n-1, i, -1):
            for m in range(0, n-1):
                print(f'{arr[m]:2}' + (' ' if m != j-1 else
                                       ' +' if arr[j-1] > arr[j] else ' -'),
                      end='')
            print(f'{arr[n-1]:2}')
            cnt += 1
            if arr[j-1] > arr[j]:
                arr[j - 1], arr[j] = arr[j], arr[j-1] # swap
                cnt2 += 1
        print()
    return arr, cnt, cnt2
                
if __name__ == "__main__":
    unsortedArr = [9, 1, 3, 4, 6, 7, 8]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr = bubbleSort(unsortedArr)
    print(f'버블 정렬 후 배열: {sortedArr[0]}')
    print(f'원솟값을 비교하는 횟수: {sortedArr[1]}')
    print(f'정렬을 위한 총 swap 횟수: {sortedArr[2]}')
# Out:
# 정렬되지 않은 배열: [9, 1, 3, 4, 6, 7, 8]
#
# 패스 1
#  9  1  3  4  6  7 - 8
#  9  1  3  4  6 - 7  8
#  9  1  3  4 - 6  7  8
#  9  1  3 - 4  6  7  8
#  9  1 - 3  4  6  7  8
#  9 + 1  3  4  6  7  8
#
# 패스 2
#  1  9  3  4  6  7 - 8
#  1  9  3  4  6 - 7  8
#  1  9  3  4 - 6  7  8
#  1  9  3 - 4  6  7  8
#  1  9 + 3  4  6  7  8
#
# 패스 3
#  1  3  9  4  6  7 - 8
#  1  3  9  4  6 - 7  8
#  1  3  9  4 - 6  7  8
#  1  3  9 + 4  6  7  8
#
# 패스 4
#  1  3  4  9  6  7 - 8
#  1  3  4  9  6 - 7  8
#  1  3  4  9 + 6  7  8
#
# 패스 5
#  1  3  4  6  9  7 - 8
#  1  3  4  6  9 + 7  8
#
# 패스 6
#  1  3  4  6  7  9 + 8
#
# 버블 정렬 후 배열: [1, 3, 4, 6, 7, 8, 9]
# 원솟값을 비교하는 횟수: 21
# 정렬을 위한 총 swap 횟수: 6

# %%
def shakerSort(arr):
    left = 0
    right = len(arr) - 1
    last = right
    
    cnt = 0
    cnt_2 = 0
    
    while left < right:
        for j in range(right, left, -1): # 정렬되지 않은 원솟값 중 최솟값 맨 앞에 fix
            if arr[j - 1] > arr[j]:
                arr[j - 1], arr[j] = arr[j], arr[j - 1]
                last = j
                cnt_2 += 1
        left = last
            
        for j in range(left, right): # 정렬되지 않은 원솟값 중 최댓값 맨 뒤에 fix
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                last = j
                cnt_2 += 1
        right = last
        
    cnt = left + right
    return arr, cnt, cnt_2

if __name__ == "__main__":
    unsortedArr = [9, 1, 3, 4, 6, 7, 8]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr = shakerSort(unsortedArr)
    print(f'버블 정렬 후 배열: {sortedArr[0]}')
    print(f'원솟값을 비교하는 횟수: {sortedArr[1]}')
    print(f'정렬을 위한 총 swap 횟수: {sortedArr[2]}')
# Out:
# 정렬되지 않은 배열: [9, 1, 3, 4, 6, 7, 8]
#
# 버블 정렬 후 배열: [1, 3, 4, 6, 7, 8, 9]
# 원솟값을 비교하는 횟수: 10
# 정렬을 위한 총 swap 횟수: 6

# %%
def shakerSort(arr):
    left = 0
    right = len(arr) - 1
    last = right
    
    cnt = 0
    cnt_2 = 0
    
    while left < right:
        for j in range(right, left, -1): # 정렬되지 않은 원솟값 중 최솟값 맨 앞에 fix
            if arr[j - 1] > arr[j]:
                arr[j - 1], arr[j] = arr[j], arr[j - 1]
                last = j
                cnt_2 += 1
        left = last
            
        for j in range(left, right): # 정렬되지 않은 원솟값 중 최댓값 맨 뒤에 fix
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                last = j
                cnt_2 += 1
        right = last
        
    cnt = left + right
    return arr, cnt, cnt_2

if __name__ == "__main__":
    unsortedArr = [23, 78, 45, 8, 32, 56]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr = shakerSort(unsortedArr)
    print(f'버블 정렬 후 배열: {sortedArr[0]}')
    print(f'원솟값을 비교하는 횟수: {sortedArr[1]}')
    print(f'정렬을 위한 총 swap 횟수: {sortedArr[2]}')
# Out:
# 정렬되지 않은 배열: [23, 78, 45, 8, 32, 56]
#
# 버블 정렬 후 배열: [8, 23, 32, 45, 56, 78]
# 원솟값을 비교하는 횟수: 6
# 정렬을 위한 총 swap 횟수: 7

# %%
def bubbleSort(arr):
    n = len(arr)
    cnt = 0
    cnt2 = 0
    for i in range(n-1): # 패스(pass)
        print(f'패스 {i+1}')
        for j in range(n-1, i, -1):
            for m in range(0, n-1):
                print(f'{arr[m]:2}' + (' ' if m != j-1 else
                                       ' +' if arr[j-1] > arr[j] else ' -'),
                      end='')
            print(f'{arr[n-1]:2}')
            cnt += 1
            if arr[j-1] > arr[j]:
                arr[j - 1], arr[j] = arr[j], arr[j-1] # swap
                cnt2 += 1
        print()
    return arr, cnt, cnt2
                
if __name__ == "__main__":
    unsortedArr = [23, 78, 45, 8, 32, 56]
    print(f'정렬되지 않은 배열: {unsortedArr}')
    print()
    sortedArr = bubbleSort(unsortedArr)
    print(f'버블 정렬 후 배열: {sortedArr[0]}')
    print(f'원솟값을 비교하는 횟수: {sortedArr[1]}')
    print(f'정렬을 위한 총 swap 횟수: {sortedArr[2]}')
# Out:
# 정렬되지 않은 배열: [23, 78, 45, 8, 32, 56]
#
# 패스 1
# 23 78 45  8 32 -56
# 23 78 45  8 -32 56
# 23 78 45 + 8 32 56
# 23 78 + 8 45 32 56
# 23 + 8 78 45 32 56
#
# 패스 2
#  8 23 78 45 32 -56
#  8 23 78 45 +32 56
#  8 23 78 +32 45 56
#  8 23 -32 78 45 56
#
# 패스 3
#  8 23 32 78 45 -56
#  8 23 32 78 +45 56
#  8 23 32 -45 78 56
#
# 패스 4
#  8 23 32 45 78 +56
#  8 23 32 45 -56 78
#
# 패스 5
#  8 23 32 45 56 -78
#
# 버블 정렬 후 배열: [8, 23, 32, 45, 56, 78]
# 원솟값을 비교하는 횟수: 15
# 정렬을 위한 총 swap 횟수: 7
